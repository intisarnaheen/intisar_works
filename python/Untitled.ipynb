# %%
#from DoubleLink import * 
from jointCtlComp import * 
#from my_ctl import * 
from my_taskSpace_ctl import * 
#from simSys import *
#from taskCtlComp import *
#%matplotlib inline

# %%
jointCtlComp(['ModelBased'], 1, 0, 'exampleJoint')
